# %%
import os
os.environ["GOOGLE_API_KEY"] ="AIzaSyB0Wn5gM91Zi-NnBFZRxV49w4VdcnEHXg8"

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

api_key=os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("google api key is not found")

#initialise the client
# genai.Client() is the client object that manages authentication (API key), requests, and responses.

client=genai.Client(api_key=api_key)

# %% [markdown]
# **thinkining capability of gemini familiy**

# %%
# New Gemini models are equipped with advanced reasoning capabilities and a structured thinking process.
# This significantly enhances their ability to handle complex tasks involving multi-step planning, such as coding, advanced mathematics,
# data analysis, and problem-solving.

# %%
response=client.models.generate_content(
    model='gemini-2.5-pro',
    contents='Explain how share market is important for our nation growth',
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(include_thoughts=True)
    )
)
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""**Deconstructing the Dynamics of National Growth Through the Lens of the Share Market**
#
# Okay, so the user wants me to explain the share market's importance for national growth.  Right, I see it as a central question: how does this seemingly abstract financial instrument actually *do* something tangible for the *real* economy?  My initial thought is to structure this in a way that doesn't patronize but also doesn't get lost in jargon. The audience seems to be someone with a basic understanding, but seeking a more in-depth economic view. I'm going to keep it professional and accessible.
#
# My first impulse is to start with some basic keyword association and then develop a logical flow to present this. Share market -> companies -> investment -> growth is how my mind works when starting. I know I have to break down what the market *does* (capital formation through IPOs and FPOs), who participates (companies and various types of investors), and the benefits, but also the risks and downsides to give a complete picture.
#
# I’m thinking I’ll start with a straightforward analogy, perhaps calling the share market the “financial engine” or the "economic heart," something relatable that immediately sets the stage.  I need to clearly define the thesis: the share market is crucial because it funnels savings into productive investments, which in turn drive economic growth. Then, I’ll outline the key functions I'll be explaining – a roadmap for the reader.
#
# The "meat" will be the core points. I will use clear headings, and break down each function into manageable bites. Capital formation is key, of course, starting with IPOs. I must explain how a company goes public to raise money, and how that money is used for R&D, factories, and hiring. These are the direct links to growth: more factories mean more jobs, R&D fuels innovation. I'll need to emphasize that this is *tangible* economic impact.
#
# Then, there’s capital allocation: I’ll explain how the market actually *chooses* which companies get funding, and I can use the analogy of investors "voting" with their money to efficiently direct capital.  This is a sophisticated concept, so I will break it down slowly.
#
# Next, I'll switch gears and discuss wealth creation – focusing on the benefits for individuals. Share price appreciation and dividends are what motivate investors. How that money gets spent or reinvested contributes to the national growth equation. The next core point will be on the signaling function: the market is a barometer.  I'll clearly explain how rising indices reflect investor confidence and a positive outlook, while a falling market may indicate trouble. This provides crucial information for decision-makers.
#
# I'll emphasize that a strong share market attracts foreign investment, which brings in foreign currency, new technology, and boosts the available capital pool. I also need to emphasize the importance of corporate governance. Publicly listed companies are held to strict standards, creating a level of transparency that boosts the overall business environment.
#
# Liquidity is essential as well – explaining how it encourages investment since people want to be able to get their money back. I need to explain what that actually means. After the specific points, I need to bring it all together with a summary: a virtuous cycle linking savings, the market, investment, growth, and wealth creation.
#
# Finally, I have to be balanced. It is crucial to address the downsides. Volatility, speculation, and potential for inequality should be acknowledged, showing a mature perspective. I'll conclude by reiterating the market's importance as an essential tool for building a prosperous nation, but with the necessary caveats. I'll need to make the writing concise, clear, and ensure the entire explanation is easy to digest.
# """,
#         thought=True
#       ),
#       Part(
#         text="""Of course. Here is a clear and comprehensive explanation of why the share market is crucial for a nation's growth, broken down into key points.
#
# ### The Share Market: The Financial Heart of a Nation
#
# Think of the share market (or stock market) as the financial heart of a nation's economy. It pumps money from those who have it (savers and investors) to those who need it to create value (companies and entrepreneurs). This circulation of capital is fundamental to economic growth.
#
# Here’s a detailed breakdown of its importance:
#
# ---
#
# #### 1. Capital Formation for Businesses
#
# This is the most direct and vital role of the share market.
#
# *   **How it works:** When a company wants to expand, launch a new product, or build a new factory, it needs a large amount of money (capital). Instead of just relying on bank loans, it can "go public" through an **Initial Public Offering (IPO)**. It sells small pieces of its ownership, called shares, to the public.
# *   **Impact on Growth:** The money raised is not for speculation; it's **productive capital**. It gets invested directly into the economy to:
#     *   **Build infrastructure** (factories, offices).
#     *   **Fund Research & Development (R&D)** for innovation.
#     *   **Create Jobs** by hiring more employees.
#     *   **Expand into new markets**, increasing the nation's overall business footprint.
#
# Without a share market, promising companies would struggle to find the massive funding needed for large-scale growth.
#
# #### 2. Efficient Allocation of Capital
#
# The market doesn't just provide capital; it directs it to where it can be used most effectively.
#
# *   **How it works:** Companies that are well-managed, innovative, and profitable will see their share prices rise. This makes it easier and cheaper for them to raise more capital in the future. Conversely, poorly performing companies will see their share prices fall, making it difficult to attract new investment.
# *   **Impact on Growth:** This acts as a natural selection mechanism. It ensures that the nation's limited financial resources are channeled towards the most promising and efficient companies, maximizing economic output and innovation.
#
# #### 3. Wealth Creation for Citizens
#
# The share market is a powerful tool for the general public to participate in the country's economic success.
#
# *   **How it works:** As companies grow and become more profitable, the value of their shares increases. Investors who own these shares see their personal wealth grow. Additionally, many companies distribute a portion of their profits to shareholders as **dividends**.
# *   **Impact on Growth:** This creates a **"wealth effect."** When people's investments grow, they feel more financially secure and tend to spend more on goods and services. This increased consumer spending is a major driver of GDP growth. It also encourages a culture of saving and investing among citizens.
#
# #### 4. An Economic Barometer
#
# The overall performance of the share market, often tracked by an index (like the S&P 500 in the US, or the Nifty 50/Sensex in India), serves as a powerful indicator of the nation's economic health.
#
# *   **How it works:** A rising market generally reflects investor confidence, positive corporate earnings, and a healthy economic outlook. A falling market often signals economic trouble, uncertainty, or a potential recession.
# *   **Impact on Growth:** This "barometer" is closely watched by:
#     *   **Policymakers:** To gauge the impact of their economic policies.
#     *   **Corporations:** To make decisions about expansion and investment.
#     *   **Foreign Investors:** To assess the risk and opportunity of investing in the country.
#
# #### 5. Attracting Foreign Investment
#
# A strong, well-regulated share market is a magnet for foreign capital.
#
# *   **How it works:** Foreign Institutional Investors (FIIs) and Foreign Direct Investment (FDI) pour billions of dollars into countries with robust and transparent markets. They buy shares in local companies, providing them with more capital.
# *   **Impact on Growth:** This influx of foreign currency strengthens the nation's currency, improves its balance of payments, and brings in global expertise and technologies. It significantly expands the pool of available capital beyond domestic savings alone.
#
# #### 6. Promoting Corporate Governance and Transparency
#
# To be listed on a stock exchange, companies must adhere to strict rules and regulations.
#
# *   **How it works:** Publicly listed companies are required to publish their financial results regularly, be audited by independent firms, and be transparent about their operations. This holds the management accountable to its shareholders.
# *   **Impact on Growth:** This culture of transparency and accountability builds trust in the business environment. It reduces corruption and mismanagement, making the country a more reliable and attractive place for both domestic and international investors.
#
# ### The Virtuous Cycle of a Healthy Share Market
#
# These functions create a powerful, self-reinforcing cycle for national growth:
#
# 1.  **Citizens save and invest** their money in the share market.
# 2.  **Companies raise capital** from the market to fund expansion and innovation.
# 3.  This investment leads to **new jobs, increased production, and economic growth (GDP)**.
# 4.  As companies prosper, their **share prices and dividends increase**, creating wealth for the citizen-investors.
# 5.  This increased wealth leads to **more savings and consumer spending**, which further fuels the cycle.
#
# **Conclusion:**
#
# The share market is far more than just a place for trading. It is an indispensable engine that channels the nation's savings into productive investments, fosters innovation, creates wealth for its citizens, and imposes a discipline of transparency on its corporations. A robust, fair, and accessible share market is a hallmark of a modern, growing economy."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-pro' prompt_feedback=None response_id='De_haMPgPOuAvr0PtLep0Ag' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1223,
#   prompt_token_count=11,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=11
#     ),
#   ],
#   thoughts_token_count=1497,
#   total_token_count=2731
# ) automatic_function_calling_history=[] parsed=None

# %%
# if we want to know how llm thinks when they are solving the users query then we just have to give the param thinking_config=types.ThinkingConfig(include_thoughts=True).
# and then llm gives what steps llm take when it was dealing with the query .
# thinking_config -- include_thought
#here in the output there is output divides into two parts first one is what llm thinking and then second part contain the llm query output

# %%
response.candidates[0].content.parts
# Out:
# [Part(
#    text="""**Deconstructing the Dynamics of National Growth Through the Lens of the Share Market**
#
#  Okay, so the user wants me to explain the share market's importance for national growth.  Right, I see it as a central question: how does this seemingly abstract financial instrument actually *do* something tangible for the *real* economy?  My initial thought is to structure this in a way that doesn't patronize but also doesn't get lost in jargon. The audience seems to be someone with a basic understanding, but seeking a more in-depth economic view. I'm going to keep it professional and accessible.
#
#  My first impulse is to start with some basic keyword association and then develop a logical flow to present this. Share market -> companies -> investment -> growth is how my mind works when starting. I know I have to break down what the market *does* (capital formation through IPOs and FPOs), who participates (companies and various types of investors), and the benefits, but also the risks and downsides to give a complete picture.
#
#  I’m thinking I’ll start with a straightforward analogy, perhaps calling the share market the “financial engine” or the "economic heart," something relatable that immediately sets the stage.  I need to clearly define the thesis: the share market is crucial because it funnels savings into productive investments, which in turn drive economic growth. Then, I’ll outline the key functions I'll be explaining – a roadmap for the reader.
#
#  The "meat" will be the core points. I will use clear headings, and break down each function into manageable bites. Capital formation is key, of course, starting with IPOs. I must explain how a company goes public to raise money, and how that money is used for R&D, factories, and hiring. These are the direct links to growth: more factories mean more jobs, R&D fuels innovation. I'll need to emphasize that this is *tangible* economic impact.
#
#  Then, there’s capital allocation: I’ll explain how the market actually *chooses* which companies get funding, and I can use the analogy of investors "voting" with their money to efficiently direct capital.  This is a sophisticated concept, so I will break it down slowly.
#
#  Next, I'll switch gears and discuss wealth creation – focusing on the benefits for individuals. Share price appreciation and dividends are what motivate investors. How that money gets spent or reinvested contributes to the national growth equation. The next core point will be on the signaling function: the market is a barometer.  I'll clearly explain how rising indices reflect investor confidence and a positive outlook, while a falling market may indicate trouble. This provides crucial information for decision-makers.
#
#  I'll emphasize that a strong share market attracts foreign investment, which brings in foreign currency, new technology, and boosts the available capital pool. I also need to emphasize the importance of corporate governance. Publicly listed companies are held to strict standards, creating a level of transparency that boosts the overall business environment.
#
#  Liquidity is essential as well – explaining how it encourages investment since people want to be able to get their money back. I need to explain what that actually means. After the specific points, I need to bring it all together with a summary: a virtuous cycle linking savings, the market, investment, growth, and wealth creation.
#
#  Finally, I have to be balanced. It is crucial to address the downsides. Volatility, speculation, and potential for inequality should be acknowledged, showing a mature perspective. I'll conclude by reiterating the market's importance as an essential tool for building a prosperous nation, but with the necessary caveats. I'll need to make the writing concise, clear, and ensure the entire explanation is easy to digest.
#  """,
#    thought=True
#  ),
#  Part(
#    text="""Of course. Here is a clear and comprehensive explanation of why the share market is crucial for a nation's growth, broken down into key points.
#
#  ### The Share Market: The Financial Heart of a Nation
#
#  Think of the share market (or stock market) as the financial heart of a nation's economy. It pumps money from those who have it (savers and investors) to those who need it to create value (companies and entrepreneurs). This circulation of capital is fundamental to economic growth.
#
#  Here’s a detailed breakdown of its importance:
#
#  ---
#
#  #### 1. Capital Formation for Businesses
#
#  This is the most direct and vital role of the share market.
#
#  *   **How it works:** When a company wants to expand, launch a new product, or build a new factory, it needs a large amount of money (capital). Instead of just relying on bank loans, it can "go public" through an **Initial Public Offering (IPO)**. It sells small pieces of its ownership, called shares, to the public.
#  *   **Impact on Growth:** The money raised is not for speculation; it's **productive capital**. It gets invested directly into the economy to:
#      *   **Build infrastructure** (factories, offices).
#      *   **Fund Research & Development (R&D)** for innovation.
#      *   **Create Jobs** by hiring more employees.
#      *   **Expand into new markets**, increasing the nation's overall business footprint.
#
#  Without a share market, promising companies would struggle to find the massive funding needed for large-scale growth.
#
#  #### 2. Efficient Allocation of Capital
#
#  The market doesn't just provide capital; it directs it to where it can be used most effectively.
#
#  *   **How it works:** Companies that are well-managed, innovative, and profitable will see their share prices rise. This makes it easier and cheaper for them to raise more capital in the future. Conversely, poorly performing companies will see their share prices fall, making it difficult to attract new investment.
#  *   **Impact on Growth:** This acts as a natural selection mechanism. It ensures that the nation's limited financial resources are channeled towards the most promising and efficient companies, maximizing economic output and innovation.
#
#  #### 3. Wealth Creation for Citizens
#
#  The share market is a powerful tool for the general public to participate in the country's economic success.
#
#  *   **How it works:** As companies grow and become more profitable, the value of their shares increases. Investors who own these shares see their personal wealth grow. Additionally, many companies distribute a portion of their profits to shareholders as **dividends**.
#  *   **Impact on Growth:** This creates a **"wealth effect."** When people's investments grow, they feel more financially secure and tend to spend more on goods and services. This increased consumer spending is a major driver of GDP growth. It also encourages a culture of saving and investing among citizens.
#
#  #### 4. An Economic Barometer
#
#  The overall performance of the share market, often tracked by an index (like the S&P 500 in the US, or the Nifty 50/Sensex in India), serves as a powerful indicator of the nation's economic health.
#
#  *   **How it works:** A rising market generally reflects investor confidence, positive corporate earnings, and a healthy economic outlook. A falling market often signals economic trouble, uncertainty, or a potential recession.
#  *   **Impact on Growth:** This "barometer" is closely watched by:
#      *   **Policymakers:** To gauge the impact of their economic policies.
#      *   **Corporations:** To make decisions about expansion and investment.
#      *   **Foreign Investors:** To assess the risk and opportunity of investing in the country.
#
#  #### 5. Attracting Foreign Investment
#
#  A strong, well-regulated share market is a magnet for foreign capital.
#
#  *   **How it works:** Foreign Institutional Investors (FIIs) and Foreign Direct Investment (FDI) pour billions of dollars into countries with robust and transparent markets. They buy shares in local companies, providing them with more capital.
#  *   **Impact on Growth:** This influx of foreign currency strengthens the nation's currency, improves its balance of payments, and brings in global expertise and technologies. It significantly expands the pool of available capital beyond domestic savings alone.
#
#  #### 6. Promoting Corporate Governance and Transparency
#
#  To be listed on a stock exchange, companies must adhere to strict rules and regulations.
#
#  *   **How it works:** Publicly listed companies are required to publish their financial results regularly, be audited by independent firms, and be transparent about their operations. This holds the management accountable to its shareholders.
#  *   **Impact on Growth:** This culture of transparency and accountability builds trust in the business environment. It reduces corruption and mismanagement, making the country a more reliable and attractive place for both domestic and international investors.
#
#  ### The Virtuous Cycle of a Healthy Share Market
#
#  These functions create a powerful, self-reinforcing cycle for national growth:
#
#  1.  **Citizens save and invest** their money in the share market.
#  2.  **Companies raise capital** from the market to fund expansion and innovation.
#  3.  This investment leads to **new jobs, increased production, and economic growth (GDP)**.
#  4.  As companies prosper, their **share prices and dividends increase**, creating wealth for the citizen-investors.
#  5.  This increased wealth leads to **more savings and consumer spending**, which further fuels the cycle.
#
#  **Conclusion:**
#
#  The share market is far more than just a place for trading. It is an indispensable engine that channels the nation's savings into productive investments, fosters innovation, creates wealth for its citizens, and imposes a discipline of transparency on its corporations. A robust, fair, and accessible share market is a hallmark of a modern, growing economy."""
#  )]

# %%
# THOUGH SUMMARIES

# Imagine you're asking Gemini (or any smart AI) to solve a complex problem — like writing code, analyzing data, or planning steps for a task.
# As the model works on your request, it doesn't just give an answer out of nowhere. Internally, it "thinks" step-by-step,
# analyzing, reasoning, and deciding what to do next — similar to how a human might work through a math problem on paper
# before writing the final answer.
# These internal steps are called the model’s “thought summary ”.

# %%
prompt = (
    "Four employees — A, B, C, and D — were in the office when a system error occurred. "
    "A says: 'B did it.' B says: 'D did it.' C says: 'I didn’t do it.' D says: 'B is lying.' "
    "Only one person is telling the truth. Who caused the error?")
response=client.models.generate_content(
    model='gemini-2.5-pro',
    contents=prompt,
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(
            include_thoughts=True
        )
    )
)

response.text
# Out:
# "This is a classic logic puzzle! Let's break it down by testing each person as the culprit.\n\nThe key is that exactly one statement is true, and the other three are false.\n\n*   **A says:** 'B did it.'\n*   **B says:** 'D did it.'\n*   **C says:** 'I didn’t do it.'\n*   **D says:** 'B is lying.'\n\nLet's test the possibilities:\n\n**Scenario 1: A did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Two true statements. This is incorrect.*\n\n**Scenario 2: B did it.**\n*   A's statement ('B did it.') is **True**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Three true statements. This is incorrect.*\n\n**Scenario 3: C did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **False**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Exactly one true statement. This is the correct scenario!*\n\n**Scenario 4: D did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **True**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **False** (because B is telling the truth).\n*   *Result: Two true statements. This is incorrect.*\n\nThe only scenario that fits the condition of having only one true statement is the one where C is the culprit.\n\n**C caused the error.**"

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Analyzing the System Error Logic Puzzle**
#
# Okay, here's what I'm thinking as I dissect this puzzle: first, it's a classic deductive reasoning problem. I need to figure out who's responsible for this system error, knowing only one person is telling the truth. I've got to consider all the possibilities.
#
# I've got the core elements: A, B, C, and D, and their statements. The constraint is the "only one truth" rule, which is the key here. I'm going to systematically test each person as the culprit. I'll need to create a mental table or scenario for each person.
#
# I'm starting with the assumption that A did it. Then, I check each statement. If A is the culprit, A's statement ("B did it") is false. B's is also false, but C's statement is true. D's is also true, because B would have been lying. But that makes two statements true! This violates the rule. So A is out.
#
# Next, I'm trying B. If B did it, A's statement ("B did it") is now true. B's is false, C's is true, and D's is true (because B is lying). This gives me three true statements, also a violation. B is also incorrect.
#
# Now I'll test C. If C did it, A's statement is false, B's is false, C's is false, and D's is true. Bingo! Only one true statement. This fits the criteria perfectly. I'll keep this case in mind.
#
# Finally, I'll go through D. If D did it, A's statement is false, B's is true, and C's is true, but D's is now false. That makes two true statements, and that's not right. So D is eliminated.
#
# So, from all four cases, only C's scenario checks out. When I assume that C caused the error, I only get one true statement: that B is lying. All the others are false. This scenario fits the given condition. Thus, C is the culprit. I think this logic is sound and easy to follow, making this conclusion the correct one.
# """,
#             thought=True
#           ),
#           Part(
#             text="""This is a classic logic puzzle! Let's break it down by testing each person as the culprit.
#
# The key is that exactly one statement is true, and the other three are false.
#
# *   **A says:** 'B did it.'
# *   **B says:** 'D did it.'
# *   **C says:** 'I didn’t do it.'
# *   **D says:** 'B is lying.'
#
# Let's test the possibilities:
#
# **Scenario 1: A did it.**
# *   A's statement ('B did it.') is **False**.
# *   B's statement ('D did it.') is **False**.
# *   C's statement ('I didn’t do it.') is **True**.
# *   D's statement ('B is lying.') is **True** (because B's statement is false).
# *   *Result: Two true statements. This is incorrect.*
#
# **Scenario 2: B did it.**
# *   A's statement ('B did it.') is **True**.
# *   B's statement ('D did it.') is **False**.
# *   C's statement ('I didn’t do it.') is **True**.
# *   D's statement ('B is lying.') is **True** (because B's statement is false).
# *   *Result: Three true statements. This is incorrect.*
#
# **Scenario 3: C did it.**
# *   A's statement ('B did it.') is **False**.
# *   B's statement ('D did it.') is **False**.
# *   C's statement ('I didn’t do it.') is **False**.
# *   D's statement ('B is lying.') is **True** (because B's statement is false).
# *   *Result: Exactly one true statement. This is the correct scenario!*
#
# **Scenario 4: D did it.**
# *   A's statement ('B did it.') is **False**.
# *   B's statement ('D did it.') is **True**.
# *   C's statement ('I didn’t do it.') is **True**.
# *   D's statement ('B is lying.') is **False** (because B is telling the truth).
# *   *Result: Two true statements. This is incorrect.*
#
# The only scenario that fits the condition of having only one true statement is the one where C is the culprit.
#
# **C caused the error.**"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-pro',
#   response_id='BvXhaNaXE-221e8PkNmGsQo',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=531,
#     prompt_token_count=71,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=71
#       ),
#     ],
#     thoughts_token_count=1359,
#     total_token_count=1961
#   )
# )

# %%
response.candidates[0].content.parts[0].text #thinking
# Out:
# '**Analyzing the System Error Logic Puzzle**\n\nOkay, here\'s what I\'m thinking as I dissect this puzzle: first, it\'s a classic deductive reasoning problem. I need to figure out who\'s responsible for this system error, knowing only one person is telling the truth. I\'ve got to consider all the possibilities.\n\nI\'ve got the core elements: A, B, C, and D, and their statements. The constraint is the "only one truth" rule, which is the key here. I\'m going to systematically test each person as the culprit. I\'ll need to create a mental table or scenario for each person.\n\nI\'m starting with the assumption that A did it. Then, I check each statement. If A is the culprit, A\'s statement ("B did it") is false. B\'s is also false, but C\'s statement is true. D\'s is also true, because B would have been lying. But that makes two statements true! This violates the rule. So A is out.\n\nNext, I\'m trying B. If B did it, A\'s statement ("B did it") is now true. B\'s is false, C\'s is true, and D\'s is true (because B is lying). This gives me three true statements, also a violation. B is also incorrect.\n\nNow I\'ll test C. If C did it, A\'s statement is false, B\'s is false, C\'s is false, and D\'s is true. Bingo! Only one true statement. This fits the criteria perfectly. I\'ll keep this case in mind.\n\nFinally, I\'ll go through D. If D did it, A\'s statement is false, B\'s is true, and C\'s is true, but D\'s is now false. That makes two true statements, and that\'s not right. So D is eliminated.\n\nSo, from all four cases, only C\'s scenario checks out. When I assume that C caused the error, I only get one true statement: that B is lying. All the others are false. This scenario fits the given condition. Thus, C is the culprit. I think this logic is sound and easy to follow, making this conclusion the correct one.\n'

# %%
response.candidates[0].content.parts[1].text #output of  query
# Out:
# "This is a classic logic puzzle! Let's break it down by testing each person as the culprit.\n\nThe key is that exactly one statement is true, and the other three are false.\n\n*   **A says:** 'B did it.'\n*   **B says:** 'D did it.'\n*   **C says:** 'I didn’t do it.'\n*   **D says:** 'B is lying.'\n\nLet's test the possibilities:\n\n**Scenario 1: A did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Two true statements. This is incorrect.*\n\n**Scenario 2: B did it.**\n*   A's statement ('B did it.') is **True**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Three true statements. This is incorrect.*\n\n**Scenario 3: C did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **False**.\n*   C's statement ('I didn’t do it.') is **False**.\n*   D's statement ('B is lying.') is **True** (because B's statement is false).\n*   *Result: Exactly one true statement. This is the correct scenario!*\n\n**Scenario 4: D did it.**\n*   A's statement ('B did it.') is **False**.\n*   B's statement ('D did it.') is **True**.\n*   C's statement ('I didn’t do it.') is **True**.\n*   D's statement ('B is lying.') is **False** (because B is telling the truth).\n*   *Result: Two true statements. This is incorrect.*\n\nThe only scenario that fits the condition of having only one true statement is the one where C is the culprit.\n\n**C caused the error.**"

# %%
#conparision with previous version
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt,
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 #conparision with previous version
# ----> 2 response = client.models.generate_content(
#       3   model="gemini-1.5-flash",
#       4   contents=prompt,
#       5   config=types.GenerateContentConfig(
#       6     thinking_config=types.ThinkingConfig(
#       7       include_thoughts=True
#       8     )
#       9   )
#      10 )
#      12 print(response.text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:6498, in Models.generate_content(self, model, contents, config)
#    6496 while remaining_remote_calls_afc > 0:
#    6497   i += 1
# -> 6498   response = self._generate_content(
#    6499       model=model, contents=contents, config=parsed_config
#    6500   )
#    6502   function_map = _extra_utils.get_function_map(parsed_config)
#    6503   if not function_map:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:5310, in Models._generate_content(self, model, contents, config)
#    5307 request_dict = _common.convert_to_dict(request_dict)
#    5308 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5310 response = self._api_client.request(
#    5311     'post', path, request_dict, http_options
#    5312 )
#    5314 if config is not None and getattr(
#    5315     config, 'should_return_http_response', None
#    5316 ):
#    5317   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1291, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1281 def request(
#    1282     self,
#    1283     http_method: str,
#    (...)   1286     http_options: Optional[HttpOptionsOrDict] = None,
#    1287 ) -> SdkHttpResponse:
#    1288   http_request = self._build_request(
#    1289       http_method, path, request_dict, http_options
#    1290   )
# -> 1291   response = self._request(http_request, http_options, stream=False)
#    1292   response_body = (
#    1293       response.response_stream[0] if response.response_stream else ''
#    1294   )
#    1295   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1127, in BaseApiClient._request(self, http_request, http_options, stream)
#    1124     retry = tenacity.Retrying(**retry_kwargs)
#    1125     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1127 return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File c:\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1104, in BaseApiClient._request_once(self, http_request, stream)
#    1096 else:
#    1097   response = self._httpx_client.request(
#    1098       method=http_request.method,
#    1099       url=http_request.url,
#    (...)   1102       timeout=http_request.timeout,
#    1103   )
# -> 1104   errors.APIError.raise_for_response(response)
#    1105   return HttpResponse(
#    1106       response.headers, response if stream else [response.text]
#    1107   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:108, in APIError.raise_for_response(cls, response)
#     106 status_code = response.status_code
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#     110   raise ServerError(status_code, response_json, response)
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
# you can control the thinking tokens that model use when generating  a response.
# higher token count is for more detailed reasoning, which can be beneficial for tackling more complex tasks
# If latency is more important, use a lower budget or infact you can turn of the thinking if required.
# this all can be done using the thinking_config parameter under the object of the class generate content config

# The thinkingBudget parameter guides the model on the number of thinking tokens to use when generating a response.
#  A higher token count generally allows for more detailed reasoning, which can be beneficial for tackling more complex tasks.
#  If latency is more important, use a lower budget or disable thinking by setting thinkingBudget to 0. 
# Setting the thinkingBudget to -1 turns on dynamic thinking, meaning the model will adjust the budget based on the complexity of the request.

client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-flash",
  #contents="Compare the Scientific Contribution of Issac Newton, Albert Einsteinand Neil Bohr.Highlight How each one shaped the physics",
  contents="Hello",
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True,
      thinkingBudget= -1
    )
  )
)

print(response.text)
# Out:
# Hello there! How can I help you today?

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Responding to a Simple Greeting**
#
# Okay, so the user said "Hello."  Seems straightforward enough.  That calls for a friendly greeting in return, right?  No need to overthink it. Keep it simple, keep it professional, and acknowledge the initial interaction.  Let's keep the conversation flowing.
# """,
#             thought=True
#           ),
#           Part(
#             text='Hello there! How can I help you today?'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='7PnhaMCWIOz-1e8P68jvwQo',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=10,
#     prompt_token_count=2,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=2
#       ),
#     ],
#     thoughts_token_count=16,
#     total_token_count=28
#   )
# )

# %%
#testing model how model is thinking when the problem is tougher
#tevaluate model thinking with the help of CAT prev year question

prompt= """

SOLVE THE PROBLEM FOR ME
Sixty-four players seeded from seed 1 to seed 64 participated in a knock-out tennis tournament. Seed 1 is the highest seed and seed 64 is the lowest seed. The tournament would be played in six rounds i.e., first round, second round, third round, quarterfinals, semi finals and final. In the first round, the player with the highest seed (i.e., 1) would play with the player with the lowest seed (i.e., 64) which is designated Match No.1.
Similarly, the player with the second highest seed (i.e., 2) would play with the player with the second lowest seed (i.e., 63), which is designated Match No.2 and so on. In the second round, the winner of the Match No.1 of the first round would play with the winner of the Match No.32 of the first round and this match is designated Match No.1 of the second round.
Similarly, the winner of the Match No.2 of the first round would play with the winner of the Match No.31 of the first round and this match is designated Match No.2 of the second round and so on. In the similar pattern the subsequent rounds will be played.

Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?

Player seeded 44
Player seeded 45
Player seeded 46
Player seeded 36
Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?

57
59
62
63
"""
response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents=prompt,
    config=types.GenerateContentConfig(
    system_instruction="you only give answers to what is asked , you dont give any other thing in your output SOlve first 2 questions",
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
)
)
print(response.text)
# Out:
# **Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?**
#
# *   **Player seeded 46**
#
# **Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?**
#
# *   **63**

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Analyzing the Tennis Tournament**
#
# Okay, so I'm diving into this tennis tournament scenario. It's a single-elimination knock-out, which means one loss and you're out. We have 64 players seeded from 1 to 64.  There are 6 rounds total: First, Second, Third, Quarterfinals, Semifinals, and the Final.  The initial setup is pretty straightforward: seed 1 plays seed 64, seed 2 plays seed 63, and so on. Basically, in the first round, seed 'i' plays seed '65-i'.
#
# The second round is a bit trickier because now the winners of those initial matchups are paired.  The winner of (1 vs 64) plays the winner of (32 vs 33), winner (2 vs 63) plays winner (31 vs 34), etc. This 'outer' versus 'inner' pairing is a key feature here.  This structure is a little atypical compared to the standard bracket where 1 faces 64 in round 1.
#
# I'm starting to visualize this in my head as a series of nested matchups. Round 3 starts with the winners of the outer matches from Round 2 playing each other and this pattern continues.  I'm labeling the two halves of the bracket.  The groups are made by who can meet before the final.
#
# I'm thinking about 'groups' of players based on who *could* potentially face each other based on their initial pairings.  I figured out that the sums of the seeds in any first-round match are always 65.  Each subsequent round seems to follow a similar "opposite" pairing pattern - the winner from earlier in the bracket plays the winner from the 'opposite' side of that round.
#
# Then I identified the two halves of the draw. It becomes clearer when I break it into "halves" where the winners are from the first 8 and the second 8 matches. I'm grouping them for a detailed path tracing and seed assessment of each path.  Players from one 'half' can't meet players from the other half before the final.
#
# Okay, let's get to the questions.
#
# **Q1: Figuring Out the Runner-Up**
#
# For the first question, I'm given that seed 43 won the tournament, and I need to determine who *cannot* be the runner-up.  I need to determine what "bracket" or "half" seed 43 is in.  I found that seed 43 is in half 2. Because they won the entire tournament, the runner-up MUST come from half 1.  I have to look at the given options, and figure out which of them are in the same half as the winner.
#
# The seed numbers must come from the specific matches in order to determine their bracket. Seed 43's round 2 match is determined by the pairing in round 1 which results in the division of the bracket into halves.  I did that for each option to see where the given seeds belonged. Since the runner-up must come from a different half and cannot play seed 43 before the final, the answer is the player in the opposite half.  The options have given me three seeds that are *impossible* candidates for runner up because they are in the same half as the winner (43).  So, I had to analyze them individually.  The other player (seed 36) can be the runner-up as they would have been in the opposite half, not directly competing against the eventual winner before the final.
#
# **Q2: Finding the Lowest Seed**
#
# Now for question 2:  I need to find the lowest possible seeded player who could face the seed 12 in the final.  Basically, who is the 'highest' seeded (lowest numbered) player who could *reach* the final from the opposite side of the draw?  This involves tracing the potential path. I determined which bracket Seed 12 is in. Because the tournament is single elimination, seed 12's potential final opponent MUST be in the opposite half.  This player would be the lowest seed number *reachable* (and therefore, the highest seed number) that could meet seed 12 in the final. Then, I had to find the smallest set to determine the least seed number.  I have to figure out all the numbers. Since seed 12 in Round 2 matches is determined by its initial pairing, I identified all the seed numbers.  I made a set for the seeds based on the Round 2 matches. Then I determined the lowest seed that could reach the final.  This comes out to be Seed 63. This is plausible because that player is at the top of the other half. It would have to have won all matches but is possible""",
#             thought=True
#           ),
#           Part(
#             text="""**Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?**
#
# *   **Player seeded 46**
#
# **Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?**
#
# *   **63**"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-pro',
#   response_id='svrhaN_ZCPS91e8PqoCsyAg',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=70,
#     prompt_token_count=390,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=390
#       ),
#     ],
#     thoughts_token_count=9978,
#     total_token_count=10438
#   )
# )

# %%
# why we have to look the thinking processs?
# assume if we dont got an output that we want then with the help of thinking process we can go throuth 
# what problem llm face when llm solve the query .
# and then we anaylze the thinking process and with the help of system instruction we improve the output

# %%
# class 10th ncert problem 

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=" From a point Q, the length of the tangent to a circle is 24 cm and the distance of Q from the centre is 25 cm. Find the radius of the circle, also find area of circle",
  config=types.GenerateContentConfig(
      system_instruction="you only  give answers to what is asked, give me exact answers no round off.",
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# The radius of the circle is 7 cm.
# The area of the circle is 49π cm².

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**My Calculated Circle Dimensions**
#
# Okay, the user wants the radius and the area of a circle. Seems straightforward, leveraging my knowledge of circle geometry and tangents. Let's see...
#
# I'll denote the circle's center as 'O', the radius as 'R', and the point of tangency from point 'Q' as 'T'.  They've given me QT = 24 cm (tangent length) and OQ = 25 cm (distance from the center to Q).
#
# I remember that a radius drawn to the point of tangency is always perpendicular to the tangent. That means triangle OQT is a right-angled triangle, with a right angle at 'T'.  I can picture this easily.
#
# Now, applying the Pythagorean theorem to triangle OQT:  OT² + QT² = OQ². I know OT is the radius 'R', QT is 24 cm, and OQ is 25 cm.  So, R² + 24² = 25².  A quick calculation gives me R² + 576 = 625.  Subtracting, I get R² = 49.  Therefore, R = √49, which means the radius R is 7 cm.
#
# With the radius in hand, finding the area is trivial. The area of a circle is πR².  Since R = 7 cm, the area is π * (7²) = 49π cm².  The user wants the *exact* answer, so I'll leave it as 49π.
# """,
#             thought=True
#           ),
#           Part(
#             text="""The radius of the circle is 7 cm.
# The area of the circle is 49π cm²."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='EgniaM2sKdS-vr0P4Iq4-As',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=23,
#     prompt_token_count=64,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=64
#       ),
#     ],
#     thoughts_token_count=321,
#     total_token_count=408
#   )
# )

# %%
# class 10th ncert problem 

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=" From a point Q, the length of the tangent to a circle is 24 cm and the distance of Q from the centre is 25 cm. Find the radius of the circle, also find area of circle",
  config=types.GenerateContentConfig(
      system_instruction="you only  give answers to what is asked, give me exact answers no round off, give me final output using the value of pie as 3.14",
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# Radius of the circle:
# Let r be the radius of the circle.
# The tangent to a circle is perpendicular to the radius at the point of tangency. This forms a right-angled triangle with the radius, the tangent, and the line segment connecting the external point Q to the center of the circle.
#
# Using the Pythagorean theorem:
# (Radius)^2 + (Length of tangent)^2 = (Distance of Q from the center)^2
# r^2 + 24^2 = 25^2
# r^2 + 576 = 625
# r^2 = 625 - 576
# r^2 = 49
# r = $\sqrt{49}$
# r = 7 cm
#
# Area of the circle:
# Area = $\pi$ * r^2
# Using $\pi$ = 3.14
# Area = 3.14 * (7)^2
# Area = 3.14 * 49
# Area = 153.86 cm^2
#
# Radius of the circle: 7 cm
# Area of the circle: 153.86 cm^2

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**My Approach to the Circle Problem**
#
# Okay, so the user wants the radius and area of a circle.  This sounds straightforward enough. I need to leverage my knowledge of geometry, specifically the relationship between tangents and radii.  The key is that the tangent line and the radius form a right angle at the point of tangency. That means the Pythagorean theorem is the tool I need.  After figuring out the radius, it's just a matter of applying the standard area formula, making sure to use the given value of pi without any rounding.  Let's break this down step-by-step:
#
# First, I'll define my variables and visualize the right triangle. C is the circle's center, T is where the tangent touches the circle, and Q is the external point. CQ is the hypotenuse, and QT is one leg. CT, which I'll call 'r', is the radius (the other leg) I'm trying to find.
#
# Applying the Pythagorean theorem:  r² + 24² = 25².  Simple algebra then gives me r² = 49, so the radius, r, is 7 cm.
#
# Now for the area.  I use the formula: Area = pi * r².  I know r is 7 cm, and I've been instructed to use pi = 3.14. So, the area is 3.14 * 7² = 3.14 * 49.
#
# I need to do the multiplication carefully.  3.14 multiplied by 49 equals 153.86. Therefore, the area of the circle is 153.86 cm².
#
# I've double-checked my work.  The radius seems correct based on the Pythagorean theorem, and the area calculation is accurate. I've used the specified value of pi and haven't rounded any intermediate steps.  I'm confident I've provided the correct answers in the requested format.
# """,
#             thought=True
#           ),
#           Part(
#             text="""Radius of the circle:
# Let r be the radius of the circle.
# The tangent to a circle is perpendicular to the radius at the point of tangency. This forms a right-angled triangle with the radius, the tangent, and the line segment connecting the external point Q to the center of the circle.
#
# Using the Pythagorean theorem:
# (Radius)^2 + (Length of tangent)^2 = (Distance of Q from the center)^2
# r^2 + 24^2 = 25^2
# r^2 + 576 = 625
# r^2 = 625 - 576
# r^2 = 49
# r = $\sqrt{49}$
# r = 7 cm
#
# Area of the circle:
# Area = $\pi$ * r^2
# Using $\pi$ = 3.14
# Area = 3.14 * (7)^2
# Area = 3.14 * 49
# Area = 153.86 cm^2
#
# Radius of the circle: 7 cm
# Area of the circle: 153.86 cm^2"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='LgniaLOjF6ic1e8PjpKE2Ag',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=248,
#     prompt_token_count=79,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=79
#       ),
#     ],
#     thoughts_token_count=443,
#     total_token_count=770
#   )
# )

# %% [markdown]
# **structured output**

# %% [markdown]
# <!-- structured output  -->

# %%
# <Structured output refers to the ability to get information from the Gemini model in a well-organized, predictable format — usually as JSON, -->
#  CSV, or a table — instead of just free-form text (unstructured output like paragraphs).

# https://ai.google.dev/gemini-api/docs/structured-output?hl=en 

# eg:-
# unstructured :- "Ajay Sati has 4 years of experience in data analytics. He worked at infosys and specializes in Python, SQL, and Power BI."
# Structured :-
#     {
#   "name": "Ajay Sati",
#   "experience": "4 years",
#   "previous_company": "Infosys",
#   "skills": ["Python", "SQL", "Power BI"]
# }


# BENEFITS
  # Store in databases
  # Feed into automated pipelines
  # Analyze with BI tools or ML models
  # Use in system-to-system communication

# %%
#  Gemini can generate either JSON or enum values as structured output.



# lets start with json first
# JSON :- JSON stands for JavaScript Object Notation.
      #It is a lightweight, human-readable format used to store and exchange structured data between systems (especially between servers and
      # web applications).
      # JSON is made of key-value pairs.
      # {
      #   "key1": "value1",
      #   "key2": 123,
      #   "key3": true,
      #   "key4": [1, 2, 3],
      #   "key5": { "nestedKey": "nestedValue" }
      # }

# %%
from pydantic import BaseModel

# %%
# GENERATING JSON.
# WE NEED TO FIRST CONFIGURE THE SCHEMA ON THE MODEL.
# "Configure a schema on the model" means you tell the model in advance exactly what kind of structured response (e.g., JSON format) you want.
#  You define this using a predefined schema  which guides the model to fill out the correct fields in the  response.

# %%
class prog_language(BaseModel):
    language_name : str
    year_created : int 
    creator : str
    use_cases: list[str]


prompt = "List some popular programming languages, and for each, include its year of creation, the creator's name, and two common use cases."

"""here we pass two params in config 1st is type of output and one another param is response schema """

response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=prompt,
    config={
        'response_mime_type':'application/json',
        'response_schema':list[prog_language]
    }

)

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text='[{"language_name":"Python","year_created":1991,"creator":"Guido van Rossum","use_cases":["Web Development","Data Science"]},{"language_name":"JavaScript","year_created":1995,"creator":"Brendan Eich","use_cases":["Web Development (frontend)","Backend Development (Node.js)"]},{"language_name":"Java","year_created":1995,"creator":"James Gosling","use_cases":["Enterprise Applications","Android Development"]},{"language_name":"C++","year_created":1979,"creator":"Bjarne Stroustrup","use_cases":["Game Development","System Programming"]},{"language_name":"Go","year_created":2009,"creator":"Robert Griesemer, Rob Pike, Ken Thompson","use_cases":["Cloud Services","Network Programming"]}]'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   parsed=[
#     prog_language(
#       creator='Guido van Rossum',
#       language_name='Python',
#       use_cases=[
#         'Web Development',
#         'Data Science',
#       ],
#       year_created=1991
#     ),
#     prog_language(
#       creator='Brendan Eich',
#       language_name='JavaScript',
#       use_cases=[
#         'Web Development (frontend)',
#         'Backend Development (Node.js)',
#       ],
#       year_created=1995
#     ),
#     prog_language(
#       creator='James Gosling',
#       language_name='Java',
#       use_cases=[
#         'Enterprise Applications',
#         'Android Development',
#       ],
#       year_created=1995
#     ),
#     prog_language(
#       creator='Bjarne Stroustrup',
#       language_name='C++',
#       use_cases=[
#         'Game Development',
#         'System Programming',
#       ],
#       year_created=1979
#     ),
#     prog_language(
#       creator='Robert Griesemer, Rob Pike, Ken Thompson',
#       language_name='Go',
#       use_cases=[
#         'Cloud Services',
#         'Network Programming',
#       ],
#       year_created=2009
#     ),
#   ],
#   response_id='9xTiaLurCtu-1e8P-aXK0Qg',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=179,
#     prompt_token_count=29,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=29
#       ),
#     ],
#     thoughts_token_count=533,
#     total_token_count=741
#   )
# )

# %%
print(response.text)
#the output is not in string formate .
# now our output is in structured formate.
# Out:
# [{"language_name":"Python","year_created":1991,"creator":"Guido van Rossum","use_cases":["Web Development","Data Science"]},{"language_name":"JavaScript","year_created":1995,"creator":"Brendan Eich","use_cases":["Web Development (frontend)","Backend Development (Node.js)"]},{"language_name":"Java","year_created":1995,"creator":"James Gosling","use_cases":["Enterprise Applications","Android Development"]},{"language_name":"C++","year_created":1979,"creator":"Bjarne Stroustrup","use_cases":["Game Development","System Programming"]},{"language_name":"Go","year_created":2009,"creator":"Robert Griesemer, Rob Pike, Ken Thompson","use_cases":["Cloud Services","Network Programming"]}]

# %%
# dataframe conversion
# we need to parse this output  into a list  of dict first

import pandas as pd 
df=pd.DataFrame([i.model_dump() for i in response.parsed])
df
# Out:
#   language_name  year_created                                   creator  \
# 0        Python          1991                          Guido van Rossum
# 1    JavaScript          1995                              Brendan Eich
# 2          Java          1995                             James Gosling
# 3           C++          1979                         Bjarne Stroustrup
# 4            Go          2009  Robert Griesemer, Rob Pike, Ken Thompson
#
#                                            use_cases
# 0                    [Web Development, Data Science]
# 1  [Web Development (frontend), Backend Developme...
# 2     [Enterprise Applications, Android Development]
# 3             [Game Development, System Programming]
# 4              [Cloud Services, Network Programming]

# %%
# response.parse #
# convert them into dict.
# list ----- dataframe

# %%
from PIL import Image 

image =Image.open("person_information_image_.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x367>

# %%
from pydantic import BaseModel
from PIL import Image 

class person(BaseModel):
    name:str
    age:str
    gender:str
    address:str
    emp_id:str
    monthly_income:str
    income_currency:str


image =Image.open("person_information_image_.png")

response=client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[image,'from the given text, exxtract all the imaformation that is available as per the given json structure'],
    config={
        'response_mime_type':'application/json',
        'response_schema':list[person]

    }
)

response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text='[{"name": "Alpha", "age": "28", "gender": "male", "address": "", "emp_id": "", "monthly_income": "12000000", "income_currency": "USD"}, {"name": "Priya", "age": "32", "gender": "female", "address": "Mumbai", "emp_id": "E-5431", "monthly_income": "1500000", "income_currency": "INR"}, {"name": "David", "age": "69", "gender": "male", "address": "Abu Dhabi, Londyee", "emp_id": "LON-889B", "monthly_income": "69000", "income_currency": "GBP"}, {"name": "Fatima Tnabi", "age": "29", "gender": "female", "address": "Abu Tokyo", "emp_id": "", "monthly_income": "1500000", "income_currency": "JPY"}, {"name": "Marcus", "age": "60", "gender": "male", "address": "Singapore", "emp_id": "", "monthly_income": "30000", "income_currency": "SGD"}, {"name": "Alpha", "age": "38", "gender": "male", "address": "Bangalore", "emp_id": "BLR-007", "monthly_income": "11000000", "income_currency": "USD"}, {"name": "Sofia", "age": "52", "gender": "male", "address": "New York", "emp_id": "B2.5-007", "monthly_income": "1000", "income_currency": "GBP"}, {"name": "Sofia", "age": "35", "gender": "female", "address": "Aler New York", "emp_id": "NYC-2024A", "monthly_income": "90000", "income_currency": "USD"}, {"name": "Omar", "age": "41", "gender": "male", "address": "Riyadh", "emp_id": "SA-9182", "monthly_income": "30000", "income_currency": "INR"}, {"name": "Chloe", "age": "25", "gender": "female", "address": "Sydney", "emp_id": "", "monthly_income": "", "income_currency": ""}, {"name": "Raj", "age": "", "gender": "male", "address": "", "emp_id": "", "monthly_income": "12000", "income_currency": "AUD"}, {"name": "Omar", "age": "22", "gender": "male", "address": "Riyadh", "emp_id": "NYC-2024A", "monthly_income": "60000", "income_currency": "SAR"}, {"name": "Ananya", "age": "", "gender": "female", "address": "Pune", "emp_id": "P-7890-INT", "monthly_income": "80000", "income_currency": "INR"}]'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   parsed=[
#     person(
#       address='',
#       age='28',
#       emp_id='',
#       gender='male',
#       income_currency='USD',
#       monthly_income='12000000',
#       name='Alpha'
#     ),
#     person(
#       address='Mumbai',
#       age='32',
#       emp_id='E-5431',
#       gender='female',
#       income_currency='INR',
#       monthly_income='1500000',
#       name='Priya'
#     ),
#     person(
#       address='Abu Dhabi, Londyee',
#       age='69',
#       emp_id='LON-889B',
#       gender='male',
#       income_currency='GBP',
#       monthly_income='69000',
#       name='David'
#     ),
#     person(
#       address='Abu Tokyo',
#       age='29',
#       emp_id='',
#       gender='female',
#       income_currency='JPY',
#       monthly_income='1500000',
#       name='Fatima Tnabi'
#     ),
#     person(
#       address='Singapore',
#       age='60',
#       emp_id='',
#       gender='male',
#       income_currency='SGD',
#       monthly_income='30000',
#       name='Marcus'
#     ),
#     <... 8 more items ...>,
#   ],
#   response_id='1RziaKPhM8iYvr0PmJzJ-Ao',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=739,
#     prompt_token_count=280,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=22
#       ),
#       ModalityTokenCount(
#         modality=<MediaModality.IMAGE: 'IMAGE'>,
#         token_count=258
#       ),
#     ],
#     thoughts_token_count=4935,
#     total_token_count=5954
#   )
# )

# %%
# dataframe conversion
# we need to parse this output  into a list  of dict first

import pandas as pd 
df=pd.DataFrame([i.model_dump() for i in response.parsed])
df
# Out:
#             name age  gender             address      emp_id monthly_income  \
# 0          Alpha  28    male                                       12000000
# 1          Priya  32  female              Mumbai      E-5431        1500000
# 2          David  69    male  Abu Dhabi, Londyee    LON-889B          69000
# 3   Fatima Tnabi  29  female           Abu Tokyo                    1500000
# 4         Marcus  60    male           Singapore                      30000
# 5          Alpha  38    male           Bangalore     BLR-007       11000000
# 6          Sofia  52    male            New York    B2.5-007           1000
# 7          Sofia  35  female       Aler New York   NYC-2024A          90000
# 8           Omar  41    male              Riyadh     SA-9182          30000
# 9          Chloe  25  female              Sydney
# 10           Raj        male                                          12000
# 11          Omar  22    male              Riyadh   NYC-2024A          60000
# 12        Ananya      female                Pune  P-7890-INT          80000
#
#    income_currency
# 0              USD
# 1              INR
# 2              GBP
# 3              JPY
# 4              SGD
# 5              USD
# 6              GBP
# 7              USD
# 8              INR
# 9
# 10             AUD
# 11             SAR
# 12             INR

# %%
# Enum stands for "Enumeration". It is a data type that defines a set of named values — called members or constants — that a variable can take.
#Think of it like a drop-down menu in a form, where only a few specific choices are allowed.

# %%
"""# Output.
    # pdf :-
        name:-
        dignosis:-
        medicines:-
        final remark:- admit , admittted, stay in hospital"""

# %%
# admit : admitted
# admitted :admitted
# stay in hospital : admitted

# %%
# problem : country:- continent

import enum


class continent(enum.Enum):
  NORTH_ASIA =  "ASIA"
  SOUTH_ASIA =  "ASIA"
  EAST_ASIA =  "ASIA"
  WEST_ASIA =  "ASIA"
  CENTRAL_ASIA =  "ASIA"
  OTHER = "NOT ASIA"


response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents="Where is PHOTOSYNTHESIS",
    config={
        "response_mime_type":"text/x.enum",
        "response_schema":continent
    }


)

# %%
print(response.text)
# Out:
# NOT ASIA
